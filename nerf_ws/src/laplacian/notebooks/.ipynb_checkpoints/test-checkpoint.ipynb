# %%
import time
import matplotlib.pyplot as plt
import torch
import numpy as np
from laplacian_py import laplacian_solver
print(laplacian_solver.__dir__())

res = 100
max_val = res//3

values = .99*max_val*torch.ones((res, res),dtype=torch.float32, device='cuda')
boundary_conditions = torch.zeros((res,res),dtype=torch.float32, device='cuda')
boundary_types = torch.zeros((res,res),dtype=torch.float32, device='cuda')


obj1_ind1 = int(res*18/30)
obj1_ind2 = int(res*2/3)
obj1_ind3 = int(res*0)
obj1_ind4 = int(res*2/3)
boundary_conditions[obj1_ind1:obj1_ind2, obj1_ind3:obj1_ind4] = max_val
boundary_types[obj1_ind1:obj1_ind2, obj1_ind3:obj1_ind4] = 1.0

obj2_ind1 = int(res*3/12)
obj2_ind2 = int(res*4/12)
obj2_ind3 = int(res*1/3)
obj2_ind4 = int(res*28/30)
boundary_conditions[obj2_ind1:obj2_ind2, obj2_ind3:obj2_ind4] = max_val
boundary_types[obj2_ind1:obj2_ind2, obj2_ind3:obj2_ind4] = 1.0

# boundary_conditions[2*60:2*80, 2*60:2*80] = 0
# boundary_types[2*60:2*80, 2*60:2*80] = 1.0

ind1 = int(res*2/30)
ind2 = int(res*2/30)
boundary_conditions[ind1, ind2] = 0.0
boundary_types[ind1, ind2] = 1.0

# ind1 = int(res*6/30)
# ind2 = int(res*22/30)
# boundary_conditions[ind1, ind2] = 0.0
# boundary_types[ind1, ind2] = 1.0

# inds = np.random.rand(boundary_conditions.shape[0], boundary_conditions.shape[1]) > .999
# boundary_conditions[inds] = 100
# boundary_types[inds] = 1.0

def get_edge_inds(grid_size, dim_index):
    offset = 1
    XYZ = [np.linspace(0, s-1, s, dtype=np.int32) for s in grid_size]
    out = np.meshgrid(*XYZ)
    tmp = np.vstack([val.flatten() for val in out])
    inds1 = tmp[dim_index, :] == 0 + offset
    inds2 = tmp[dim_index, :] == grid_size[dim_index] -1 -offset
    inds = np.any(np.vstack([inds1, inds2]), axis=0)
    return np.reshape(inds, grid_size) 

# edge_inds_x = get_edge_inds(values.shape, 0)
# boundary_conditions[edge_inds_x] = 40
# boundary_types[edge_inds_x] = 1 # flux x

# edge_inds_y = get_edge_inds(values.shape, 1)
# boundary_conditions[edge_inds_y] = 40
# boundary_types[edge_inds_y] = 1 # flux y

XYZ = [np.linspace(0, 1, res, dtype=np.float32) for _ in range(2)]
X, Y = np.meshgrid(*XYZ)
# cost = .005*torch.tensor(10*(1-X)*(1-Y),dtype=torch.float32, device='cuda')
cost_scale = .005
cost = cost_scale*torch.ones(res,res,dtype=torch.float32, device='cuda')
safe = res//15
cost[max(obj1_ind1-safe, 0):min(obj1_ind2+safe, res-1), max(obj1_ind3-safe, 0):min(obj1_ind4+safe, res-1)] = .3
cost[max(obj2_ind1-safe, 0):min(obj2_ind2+safe, res-1), max(obj2_ind3-safe, 0):min(obj2_ind4+safe, res-1)] = .3




# start = time.time()
# x = np.zeros((100,100),dtype=np.float32)
# for i in range(100000):
#     x = x + 1
# end = time.time()
# print(end - start)
# Out:
# ['__name__', '__doc__', '__package__', '__loader__', '__spec__', 'forward', 'backward', '__file__']

# %%
from torch.autograd import Function
from torch.autograd.function import once_differentiable

class LaplacianSolver(Function):
    @staticmethod
    def forward(ctx, V: torch.Tensor, C: torch.Tensor):
        X = torch.stack([V, boundary_types, boundary_conditions, C], axis=2)
        intermediate = [C] 
        for i in range(10):
            intermediate.append(X[:, :, 0].clone())
            laplacian_solver.forward(X)
        ctx.save_for_backward(*intermediate)
        out = X[:, :, 0].clone()    
        
        return out
    
    @staticmethod
    @once_differentiable
    def backward(ctx, dL_dout):
        # dL_dX how loss change with output X
        intermediate = ctx.saved_tensors
        grid_size = intermediate[0].shape
        dL_dC = torch.zeros(grid_size, dtype=torch.float32, device='cuda')
        
        C = intermediate[0]
        dL_dC_i = torch.zeros(grid_size, dtype=torch.float32, device='cuda')
        dL_dV_i = torch.zeros(grid_size, dtype=torch.float32, device='cuda')
        dL_dout_i = dL_dout
        for V in intermediate[-1:0:-1]:
            X = torch.stack([V, boundary_types, boundary_conditions, C], axis=2)
            laplacian_solver.backward(X, dL_dout_i, dL_dV_i, dL_dC_i)
            dL_dC += dL_dC_i
            dL_dout_i = dL_dV_i
            
        return dL_dV_i, dL_dC

V =  values
C =  cost

# %%
V = V.detach().requires_grad_(True)
C = C.detach().requires_grad_(True)
layer = LaplacianSolver()
forward = layer.apply
start = time.time()
out = forward(V, C)

end = time.time()
print(end - start)

loss = torch.sum((out)**2)
loss.backward()

# print(C.grad)
# print(V.grad)
# import sys
# np.set_printoptions(threshold=sys.maxsize)
# print(V.cpu().detach().numpy())
# print(V.grad.cpu().numpy())

z = V.grad.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z)
plt.colorbar()
plt.contour(z)
plt.show()

z = C.grad.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z)
plt.colorbar()
plt.contour(z)
plt.show()

V = out.detach()

z = V.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z)
plt.colorbar()
plt.contour(z)
plt.show()

# print(torch.cuda.memory_summary() )
# Out:
# 0.0003371238708496094

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X = np.linspace(-1, 1, z.shape[0])
Y = np.linspace(-1, 1, z.shape[1])
X, Y = np.meshgrid(X, Y)
surf = ax.plot_surface(X,Y,z,linewidth=0, antialiased=False)

# %%
import sympy
from sympy import *

V_s = [symbols('V_{'+f'{i}\_{j}' +'}') for i in [-1,0,1] for j in [-1,0,1] if i!=0 or j!=0]
# V = symbols(f'V00')
c_s = symbols(f'c00')
init_printing(use_unicode=True, wrap_line=False)

expression = c_s + sum([vi*exp(-vi+717)/(sum([exp(-vj+717) for vj in V_s])) for vi in V_s])
expression
# Out:
#                                                                         717 - V_{-1\_-1}                                                                                                                                      717 - V_{-1\_0}                                                                                                                                       717 - V_{-1\_1}                                                                                                                                       717 - V_{0\_-1}                                                                                                                                       717 - V_{0\_1}                                                                                                                                        717 - V_{1\_-1}                                                                                                                                       717 - V_{1\_0}                                                                                                                                        717 - V_{1\_1}
#                                                             V_{-1\_-1}⋅ℯ                                                                                                                                           V_{-1\_0}⋅ℯ                                                                                                                                           V_{-1\_1}⋅ℯ                                                                                                                                           V_{0\_-1}⋅ℯ                                                                                                                                            V_{0\_1}⋅ℯ                                                                                                                                           V_{1\_-1}⋅ℯ                                                                                                                                            V_{1\_0}⋅ℯ                                                                                                                                            V_{1\_1}⋅ℯ
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + c₀₀
#  717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}
# ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ

# %%
print(f'd/d{V_s[0].name}')
derivative = diff(expression, V_s[0])
derivative
# Out:
# d/dV_{-1\_-1}
#                                                                           717 - V_{-1\_-1}                                                                                                                                     1434 - 2⋅V_{-1\_-1}                                                                                                                               717 - V_{-1\_-1}  717 - V_{-1\_0}                                                                                                                        717 - V_{-1\_-1}  717 - V_{-1\_1}                                                                                                                        717 - V_{-1\_-1}  717 - V_{0\_-1}                                                                                                                        717 - V_{-1\_-1}  717 - V_{0\_1}                                                                                                                         717 - V_{-1\_-1}  717 - V_{1\_-1}                                                                                                                        717 - V_{-1\_-1}  717 - V_{1\_0}                                                                                                                         717 - V_{-1\_-1}  717 - V_{1\_1}                                                                                                                           717 - V_{-1\_-1}
#                                                               V_{-1\_-1}⋅ℯ                                                                                                                                         V_{-1\_-1}⋅ℯ                                                                                                                                       V_{-1\_0}⋅ℯ                ⋅ℯ                                                                                                                            V_{-1\_1}⋅ℯ                ⋅ℯ                                                                                                                            V_{0\_-1}⋅ℯ                ⋅ℯ                                                                                                                             V_{0\_1}⋅ℯ                ⋅ℯ                                                                                                                            V_{1\_-1}⋅ℯ                ⋅ℯ                                                                                                                             V_{1\_0}⋅ℯ                ⋅ℯ                                                                                                                             V_{1\_1}⋅ℯ                ⋅ℯ                                                                                                                                        ℯ
# - ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}                                                                                                                                                        2                                                                                                                                                        2                                                                                                                                                        2                                                                                                                                                        2                                                                                                                                                        2                                                                                                                                                        2                                                                                                                                                        2                                                                                                                                                        2    717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}
#   ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                 ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞    ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ
#                                                                                                                                                         ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠    ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠

# %%
# factor = 1/(sum([exp(-vj) for vj in V_s]))
factor = sum([exp(-vj+717) for vj in V_s])
derivative = sympy.collect(derivative, factor)
# derivative = derivative.simplify()
# derivative = derivative.simplify()
# factor
derivative
# Out:
#                                                                717 - V_{-1\_-1}    717 - V_{-1\_-1}                                                               1434 - 2⋅V_{-1\_-1}              717 - V_{-1\_-1}  717 - V_{-1\_0}              717 - V_{-1\_-1}  717 - V_{-1\_1}              717 - V_{-1\_-1}  717 - V_{0\_-1}             717 - V_{-1\_-1}  717 - V_{0\_1}              717 - V_{-1\_-1}  717 - V_{1\_-1}             717 - V_{-1\_-1}  717 - V_{1\_0}             717 - V_{-1\_-1}  717 - V_{1\_1}
#                                                  - V_{-1\_-1}⋅ℯ                 + ℯ                                                                   V_{-1\_-1}⋅ℯ                    + V_{-1\_0}⋅ℯ                ⋅ℯ                + V_{-1\_1}⋅ℯ                ⋅ℯ                + V_{0\_-1}⋅ℯ                ⋅ℯ                + V_{0\_1}⋅ℯ                ⋅ℯ               + V_{1\_-1}⋅ℯ                ⋅ℯ                + V_{1\_0}⋅ℯ                ⋅ℯ               + V_{1\_1}⋅ℯ                ⋅ℯ
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}                                                                                                                                                                                                                                                              2
# ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                                                                                                                       ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞
#                                                                                                                                                                                                                                                             ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠

# %%
derivative
# Out:
#                                                                717 - V_{-1\_-1}    717 - V_{-1\_-1}                                                               1434 - 2⋅V_{-1\_-1}              717 - V_{-1\_-1}  717 - V_{-1\_0}              717 - V_{-1\_-1}  717 - V_{-1\_1}              717 - V_{-1\_-1}  717 - V_{0\_-1}             717 - V_{-1\_-1}  717 - V_{0\_1}              717 - V_{-1\_-1}  717 - V_{1\_-1}             717 - V_{-1\_-1}  717 - V_{1\_0}             717 - V_{-1\_-1}  717 - V_{1\_1}
#                                                  - V_{-1\_-1}⋅ℯ                 + ℯ                                                                   V_{-1\_-1}⋅ℯ                    + V_{-1\_0}⋅ℯ                ⋅ℯ                + V_{-1\_1}⋅ℯ                ⋅ℯ                + V_{0\_-1}⋅ℯ                ⋅ℯ                + V_{0\_1}⋅ℯ                ⋅ℯ               + V_{1\_-1}⋅ℯ                ⋅ℯ                + V_{1\_0}⋅ℯ                ⋅ℯ               + V_{1\_1}⋅ℯ                ⋅ℯ
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}                                                                                                                                                                                                                                                              2
# ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ                                                                                                                       ⎛ 717 - V_{-1\_-1}    717 - V_{-1\_0}    717 - V_{-1\_1}    717 - V_{0\_-1}    717 - V_{0\_1}    717 - V_{1\_-1}    717 - V_{1\_0}    717 - V_{1\_1}⎞
#                                                                                                                                                                                                                                                             ⎝ℯ                 + ℯ                + ℯ                + ℯ                + ℯ               + ℯ                + ℯ               + ℯ              ⎠

# %%
print('d/dc')
diff(expression, c_s)
# Out:
# d/dc
# 1

# %%
import torch.nn as nn
import torch.utils.data
import torch.nn.functional as F
import torch.optim as optim


inds = values >= max_val

class LaplaceNet(nn.Module):
    def __init__(self):
        super(LaplaceNet, self).__init__()
        self.C = nn.Parameter(cost_scale*torch.ones(res,res,dtype=torch.float32, device='cuda'))
#         self.V = [max_val*torch.ones((res, res),dtype=torch.float32, device='cuda')]
        layer = LaplacianSolver()
        self.solve = layer.apply
        
    
    def forward(self, x):
#         C_pos = 5*cost_scale*(torch.tanh(self.C) + 1)
#         C_pos = cost_scale*(torch.exp(self.C))
        C_pos = F.relu(self.C)
        out = self.solve(x, C_pos)
        out[out >= max_val] = .95*max_val
        out[inds] = max_val
        return out, C_pos

def compute_loss(pred, target, C_pos):
#     loss = F.huber_loss(pred, target)
    loss = torch.sum((pred - target)**2)/pred.numel()
#     if torch.any(C_pos[C_pos < 0]):
    loss = loss + 5*torch.sum((C_pos - .01*cost_scale)**2)/torch.sum(C_pos)
    return loss
    
network = LaplaceNet()
network.cuda(device='cuda')
V_in = V.clone()

# %%
# lr = 5e-0 #huber
# lr = 1e-0 # norm
lr = 1e-5 # norm6

momentum = 0.99

XYZ = [np.linspace(0, 1, res, dtype=np.float32) for _ in range(2)]
X, Y = np.meshgrid(*XYZ)
# target = torch.tensor(20*Y + 0,dtype=torch.float32, device='cuda')
# target = torch.tensor(20*X + 0,dtype=torch.float32, device='cuda')
# target = torch.tensor(12*(X**2+Y**2) + 0,dtype=torch.float32, device='cuda')
# target = torch.tensor(15 + 0*X,dtype=torch.float32, device='cuda')
target = torch.tensor(10*Y + 10*(1-X), dtype=torch.float32, device='cuda')
# target = torch.tensor(10*(1-Y) + 10*X, dtype=torch.float32, device='cuda')

optimizer = optim.SGD(network.parameters(), lr=lr, momentum=momentum)

for it in range(0, 8000):
    optimizer.zero_grad()
    pred, C_pos = network(V_in)
    V_in = pred.detach()
    loss_train = compute_loss(pred=pred, target=target, C_pos=C_pos)
    if it % 10 == 0:
        print(loss_train)
    loss_train.backward()
    optimizer.step()
    
    
z = pred.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z)
plt.colorbar()
plt.contour(z)
plt.show()


z2 = target.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z2)
plt.colorbar()
plt.contour(z2)
plt.show()

z3 = C_pos.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z3)
plt.colorbar()
plt.contour(z3)
plt.show()

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X = np.linspace(-1, 1, z.shape[0])
Y = np.linspace(-1, 1, z.shape[1])
X, Y = np.meshgrid(X, Y)
surf = ax.plot_surface(X,Y,z,linewidth=0, antialiased=False)
# Out:
# tensor(549.6967, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(169.3333, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(143.7207, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(137.7830, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(132.2166, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(126.9914, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(122.0816, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(117.4660, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(113.1291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(109.0609, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(105.2570, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(101.7191, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(98.4555, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(95.4793, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(92.8073, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(90.4595, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(88.4571, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.8226, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.5789, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.7404, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2994, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2102, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.3781, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.6916, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.0688, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.4574, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.8182, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.1178, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.3296, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.4450, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.4844, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.4812, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.4591, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.4291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.3957, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.3604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.3237, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.2860, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.2474, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.2081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.1680, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.1274, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.0862, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.0444, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(86.0022, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.9595, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.9165, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.8731, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.8293, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.7852, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.7408, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.6960, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.6510, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.6056, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.5600, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.5140, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.4678, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.4212, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.3743, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.3274, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.2808, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.2345, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.1888, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.1437, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.0993, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.0558, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(85.0131, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.9713, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.9304, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.8905, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.8516, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.8137, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.7766, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.7406, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.7055, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.6713, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.6380, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.6056, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.5740, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.5433, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.5133, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.4841, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.4556, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.4278, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.4006, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.3741, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.3483, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.3230, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2983, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2741, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2504, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2272, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.2045, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.1822, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.1604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.1390, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.1179, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.0972, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.0769, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.0569, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.0372, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(84.0178, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.9987, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.9799, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.9613, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.9430, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.9249, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.9071, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.8894, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.8720, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.8547, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.8376, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.8207, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.8040, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.7874, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.7710, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.7547, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.7385, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.7224, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.7065, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.6907, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.6750, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.6594, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.6439, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.6285, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.6132, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5979, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5828, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5677, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5527, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5378, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5229, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.5081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4933, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4786, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4640, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4494, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4349, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4204, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.4059, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3915, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3772, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3628, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3486, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3343, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3201, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.3060, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2918, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2777, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2636, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2496, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2356, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2216, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.2076, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1937, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1798, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1659, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1521, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1383, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1245, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.1107, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0970, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0832, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0695, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0559, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0422, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0286, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0150, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(83.0015, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9879, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9744, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9609, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9474, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9340, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9206, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.9072, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8938, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8805, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8671, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8539, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8406, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8274, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8142, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.8010, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7878, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7747, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7616, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7485, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7355, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7224, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.7094, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6965, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6836, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6707, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6578, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6450, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6322, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6194, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.6067, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5940, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5813, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5687, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5561, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5435, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5310, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5185, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.5060, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4936, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4812, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4689, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4566, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4443, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4320, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4198, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.4077, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3956, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3835, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3714, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3595, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3475, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3356, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3237, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3119, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.3001, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2883, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2766, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2649, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2533, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2417, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2302, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2187, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.2072, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1844, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1731, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1618, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1506, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1394, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1282, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1171, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.1061, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0951, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0841, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0732, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0623, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0515, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0407, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0299, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0192, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(82.0086, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9980, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9875, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9770, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9665, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9561, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9457, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9354, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9252, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9149, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.9048, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8946, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8846, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8745, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8646, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8546, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8447, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8349, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8251, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8153, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.8056, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7960, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7864, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7768, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7673, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7578, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7484, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7390, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7297, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7204, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7112, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.7021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6929, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6839, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6748, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6659, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6569, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6480, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6392, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6304, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6217, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6130, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.6044, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5872, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5787, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5703, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5618, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5535, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5452, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5369, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5287, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5205, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5124, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.5043, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4963, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4883, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4803, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4724, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4646, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4568, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4490, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4413, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4336, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4260, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4184, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4109, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.4034, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3960, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3886, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3812, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3739, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3666, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3594, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3522, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3451, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3380, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3310, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3240, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3170, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3101, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.3032, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2964, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2828, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2761, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2694, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2628, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2562, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2497, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2431, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2367, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2303, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2239, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2175, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2112, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.2050, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1987, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1926, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1864, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1803, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1742, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1682, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1622, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1562, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1503, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1444, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1385, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1327, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1270, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1212, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1155, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1098, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.1042, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0986, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0930, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0875, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0820, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0766, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0711, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0658, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0551, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0498, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0446, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0394, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0342, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0240, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0189, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0138, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0088, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(81.0038, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9989, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9940, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9891, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9843, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9795, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9747, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9699, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9652, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9605, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9559, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9512, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9467, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9421, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9376, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9330, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9286, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9241, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9197, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9153, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9110, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9066, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.9024, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8981, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8938, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8854, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8813, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8772, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8730, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8690, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8649, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8609, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8569, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8530, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8490, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8451, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8412, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8374, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8336, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8298, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8260, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8223, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8185, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8148, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8112, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8075, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8039, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.8003, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7967, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7932, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7861, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7826, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7792, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7757, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7723, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7689, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7655, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7622, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7589, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7556, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7523, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7490, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7458, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7425, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7394, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7362, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7330, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7299, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7268, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7237, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7206, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7145, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7115, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7085, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7056, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.7026, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6997, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6967, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6938, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6909, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6880, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6852, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6824, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6795, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6767, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6739, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6712, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6684, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6657, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6630, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6603, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6576, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6549, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6523, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6497, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6470, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6445, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6419, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6394, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6368, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6343, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6318, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6293, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6269, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6244, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6220, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6196, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6172, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6149, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6125, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6102, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6078, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6055, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6032, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.6010, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5987, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5964, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5942, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5920, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5898, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5876, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5854, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5833, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5811, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5790, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5769, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5748, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5727, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5707, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5686, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5666, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5645, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5625, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5605, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5585, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5566, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5546, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5526, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5507, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5487, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5468, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5449, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5430, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5411, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5393, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5374, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5355, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5337, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5319, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5300, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5282, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5264, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5247, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5229, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5211, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5194, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5177, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5160, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5143, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5126, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5109, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5092, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5076, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5059, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5043, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5027, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.5011, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4995, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4979, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4963, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4947, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4932, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4916, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4901, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4886, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4871, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4856, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4841, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4826, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4811, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4796, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4782, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4767, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4753, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4739, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4724, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4710, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4696, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4682, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4669, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4655, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4641, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4628, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4614, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4601, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4588, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4575, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4562, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4549, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4536, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4523, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4510, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4498, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4485, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4473, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4461, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4448, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4436, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4412, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4400, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4388, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4377, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4365, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4353, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4342, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4330, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4319, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4307, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4296, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4284, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4273, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4262, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4251, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4240, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4229, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4218, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4207, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4196, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4185, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4174, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4164, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4153, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4143, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4132, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4122, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4111, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4101, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4091, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4071, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4061, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4051, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4041, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4031, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4011, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.4001, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3992, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3982, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3972, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3963, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3953, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3944, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3934, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3925, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3916, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3906, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3897, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3888, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3879, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3870, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3861, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3852, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3843, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3834, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3825, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3816, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3807, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3799, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3790, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3782, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3773, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3765, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3756, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3748, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3740, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3732, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3723, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3715, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3707, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3699, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3691, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3683, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3675, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3667, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3660, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3652, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3644, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3636, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3629, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3621, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3613, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3606, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3598, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3590, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3583, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3575, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3568, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3560, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3553, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3546, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3538, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3531, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3524, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3516, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3509, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3502, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3495, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3488, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3481, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3474, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3467, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3460, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3453, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3446, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3439, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3432, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3425, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3418, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3412, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3405, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3398, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3391, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3385, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3378, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3371, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3365, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3358, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3352, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3345, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3339, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3332, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3326, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3319, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3313, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3306, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3300, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3294, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3287, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3281, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3275, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3269, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3262, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3256, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3250, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3244, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3237, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3231, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3225, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3219, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3213, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3207, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3201, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3194, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3188, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3182, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3170, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3164, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3158, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3152, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3146, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3140, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3134, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3129, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3123, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3117, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3111, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3105, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3099, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3093, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3087, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3082, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3076, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3070, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3064, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3059, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3053, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3047, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3042, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3036, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3030, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3025, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3019, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3014, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3008, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.3003, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2997, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2992, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2986, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2981, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2975, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2970, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2965, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2959, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2954, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2949, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2943, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2938, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2933, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2928, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2922, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2917, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2912, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2907, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2902, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2891, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2886, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2881, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2876, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2871, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2866, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2861, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(80.2856, device='cuda:0', grad_fn=<AddBackward0>)

# %%
z = pred.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z)
plt.colorbar()
cs = plt.contourf(z, levels=list(np.linspace(np.min(z),np.max(z), 50)))
plt.contour(cs, colors='k')
plt.show()

# %%
z2 = target.cpu().detach().numpy()[1:-1, 1:-1]
plt.pcolormesh(z)
plt.colorbar()
cs = plt.contourf(z2, levels=list(np.linspace(np.min(z2), np.max(z2), 50)))
plt.contour(cs, colors='k')
plt.show()

# %%
z3 = C_pos.cpu().detach().numpy()[1:-1, 1:-1]
z3[boundary_types[1:-1,1:-1].cpu().numpy() !=0] = 0
plt.pcolormesh(z3)
plt.colorbar()
plt.contour(z3)
plt.show()

# %%
z3 = abs(z2-z)
z3[boundary_types[1:-1,1:-1].cpu().numpy() !=0] = 1
plt.pcolormesh(z3)
plt.colorbar()
plt.show()
